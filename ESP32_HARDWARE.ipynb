# %%
# CONNECT ESP32 module and check the ip through command arp -a of Esp32 cam and copy the ip in the url section below. 
# Ensure Proper Lightening for project to work properly as quality of esp32 is very less.

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
import urllib.request
import numpy as np
from cvlib.object_detection import draw_bbox
import concurrent.futures
 
url='http://192.168.176.195/'
im=None
 
def run1():
    cv2.namedWindow("live transmission", cv2.WINDOW_AUTOSIZE)
    while True:
        img_resp=urllib.request.urlopen(url)
        imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
        im = cv2.imdecode(imgnp,-1)
 
        cv2.imshow('live transmission',im)
        key=cv2.waitKey(5)
        if key==ord('q'):
            break
            
    cv2.destroyAllWindows()
        
def run2():
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)
    while True:
        img_resp=urllib.request.urlopen(url)
        imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
        im = cv2.imdecode(imgnp,-1)
 
        bbox, label, conf = cv.detect_common_objects(im)
        im = draw_bbox(im, bbox, label, conf)
 
        cv2.imshow('detection',im)
        key=cv2.waitKey(5)
        if key==ord('q'):
            break
            
    cv2.destroyAllWindows()
 
 
 
if __name__ == '__main__':
    print("started")
    with concurrent.futures.ProcessPoolExecutor() as executer:
            f1= executer.submit(run1)
            f2= executer.submit(run2)

# %%
#IGNORE THE CELL BELOW ....CODE FOR CHECHING AND WORKING OF ABOVE CODE

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
import urllib.request
import numpy as np
from cvlib.object_detection import draw_bbox
import concurrent.futures
 
url='http://192.168.176.195/'
im=None
 
def run1():
    cv2.namedWindow("live transmission", cv2.WINDOW_AUTOSIZE)
    while True:
        img_resp=urllib.request.urlopen(url)
        imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
        im = cv2.imdecode(imgnp,-1)
 
        cv2.imshow('live transmission',im)
        key=cv2.waitKey(5)
        if key==ord('q'):
            break
            
    cv2.destroyAllWindows()
        
def run2():
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)
    while True:
        img_resp=urllib.request.urlopen(url)
        imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
        im = cv2.imdecode(imgnp,-1)
 
        bbox, label, conf = cv.detect_common_objects(im)
        im = draw_bbox(im, bbox, label, conf)
 
        cv2.imshow('detection',im)
        key=cv2.waitKey(5)
        if key==ord('q'):
            break
            
    cv2.destroyAllWindows()
 
 
 
if __name__ == '__main__':
    print("started")
    with concurrent.futures.ProcessPoolExecutor() as executer:
            f1= executer.submit(run1)
            f2= executer.submit(run2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 model = tf.keras.models.load_model('model.h5')
#
# NameError: name 'tf' is not defined

# %%
#IGNORE THE CELLS BELOW

# %%
path = r'F:\Final Year Project\Latest_4_2_23\check_images\25.jpg'
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Define list of class names for your custom dataset
class_names = ['arbus precatorius','madagascar periwinkle','castor oil plant','dieffenbachia','fox glove','lilies','lily of the valley','oleander','pothos','rhubarb','wisteria']

# Load pre-trained EfficientNetV2B3 model
model = tf.keras.models.load_model('model.h5')

# Load image to predict
img_path = path
img = image.load_img(img_path, target_size=(300, 300))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = tf.keras.applications.efficientnet.preprocess_input(x)

# Make prediction
preds = model.predict(x)
class_idx = np.argmax(preds[0])
class_name = class_names[class_idx]
print('Predicted class:', class_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 14>()
#      12 # Load image to predict
#      13 img_path = path
# ---> 14 img = image.load_img(img_path, target_size=(300, 300))
#      15 x = image.img_to_array(img)
#      16 x = np.expand_dims(x, axis=0)
#
# File c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\keras\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'F:\\Final Year Project\\Latest_4_2_23\\check_images\\25.jpg'

# %%
path = r'F:\Final Year Project\Latest_4_2_23\check_images\27.jpg'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Define list of class names for your custom dataset
class_names = ['arbus precatorius','madagascar periwinkle','castor oil plant','dieffenbachia','fox glove','lilies','lily of the valley','oleander','pothos','rhubarb','wisteria']

# Load pre-trained EfficientNetV2B3 model
model = tf.keras.models.load_model('model.h5')

# Load image to predict
img_path = path
img = image.load_img(img_path, target_size=(300, 300))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = tf.keras.applications.efficientnet.preprocess_input(x)

# Make prediction
preds = model.predict(x)
max_pred = np.max(preds)
if max_pred < 0.5:
    class_name = "Not Identified"
else:
    class_idx = np.argmax(preds[0])
    class_name = class_names[class_idx]

print('Predicted class:', class_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 12>()
#       9 model = tf.keras.models.load_model('model.h5')
#      11 # Load image to predict
# ---> 12 img_path = path
#      13 img = image.load_img(img_path, target_size=(300, 300))
#      14 x = image.img_to_array(img)
#
# NameError: name 'path' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import cv2

# Define list of class names for your custom dataset
class_names = ['arbus precatorius','madagascar periwinkle','castor oil plant','dieffenbachia','fox glove','lilies','lily of the valley','oleander','pothos','rhubarb','wisteria']

# Load pre-trained EfficientNetV2B3 model
model = tf.keras.models.load_model('model.h5')

# Start the camera
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Preprocess the image
    img = cv2.resize(frame, (300, 300))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.efficientnet.preprocess_input(x)

    # Make prediction
    preds = model.predict(x)
    max_pred = np.max(preds)
    if max_pred < 0.3:
        class_name = "Not Identified"
    else:
        class_idx = np.argmax(preds[0])
        class_name = class_names[class_idx]

    # Display the result on the frame
    cv2.putText(frame, "Predicted class: {}".format(class_name), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    cv2.imshow('frame', frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 250ms/step

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
import urllib.request
import numpy as np
from cvlib.object_detection import draw_bbox
import concurrent.futures
 
url='http://192.168.176.195/'
im=None
 
def run1():
    cv2.namedWindow("live transmission", cv2.WINDOW_AUTOSIZE)
    while True:
        img_resp=urllib.request.urlopen(url)
        imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
        im = cv2.imdecode(imgnp,-1)
 
        cv2.imshow('live transmission',im)
        key=cv2.waitKey(5)
        if key==ord('q'):
            break
            
    cv2.destroyAllWindows()
        
def run2():
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)
    while True:
        img_resp=urllib.request.urlopen(url)
        imgnp=np.array(bytearray(img_resp.read()),dtype=np.uint8)
        im = cv2.imdecode(imgnp,-1)
 
        bbox, label, conf = cv.detect_common_objects(im)
        im = draw_bbox(im, bbox, label, conf)
 
        cv2.imshow('detection',im)
        key=cv2.waitKey(5)
        if key==ord('q'):
            break
            
    cv2.destroyAllWindows()
 
 
 
if __name__ == '__main__':
    print("started")
    with concurrent.futures.ProcessPoolExecutor() as executer:
            f1= executer.submit(run1)
            f2= executer.submit(run2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import cv2
#       2 import matplotlib.pyplot as plt
# ----> 3 import cvlib as cv
#       4 import urllib.request
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'cvlib'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
model = tf.keras.models.load_model('model.h5')

# %%
#http://192.168.137.235/

# %%
import requests
import cv2
import numpy as np
import io

# Define list of class names for your custom dataset
class_names = ['arbus precatorius','madagascar periwinkle','castor oil plant','dieffenbachia','fox glove','lilies','lily of the valley','oleander','pothos','rhubarb','wisteria']

# Set up the URL for your ESP32 server
url = 'http://http://192.168.73.195'

# Set up a loop to continuously capture and process images from the ESP32 camera
while True:
    # Send a GET request to the ESP32 server to capture an image
    response = requests.get(url)
    img_bytes = io.BytesIO(response.content).read()

    # Convert the received image bytes to a NumPy array
    img_array = np.frombuffer(img_bytes, dtype=np.uint8)

    # Decode the NumPy array to an OpenCV image
    img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

    # Preprocess the image
    img = cv2.resize(img, (900, 900))
    x = img.astype('float32')
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.efficientnet.preprocess_input(x)

    # Make prediction
    preds = model.predict(x)
    max_pred = np.max(preds)
    if max_pred < 0.3:
        class_name = "Not Identified"
    else:
        class_idx = np.argmax(preds[0])
        class_name = class_names[class_idx]

    # Display the result on the frame
    cv2.putText(img, "Predicted class: {}".format(class_name), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    cv2.imshow('frame', img)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py:159, in HTTPConnection._new_conn(self)
#     158 try:
# --> 159     conn = connection.create_connection(
#     160         (self._dns_host, self.port), self.timeout, **extra_kw
#     161     )
#     163 except SocketTimeout:
#
# File c:\users\administrator\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\connection.py:61, in create_connection(address, timeout, source_address, socket_options)
#      59 family = allowed_gai_family()
# ---> 61 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import requests
import cv2
import numpy as np
import io
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
# Define list of class names for your custom dataset
class_names = ['arbus precatorius','madagascar periwinkle','castor oil plant','dieffenbachia','fox glove','lilies','lily of the valley','oleander','pothos','rhubarb','wisteria']
model = tf.keras.models.load_model('model.h5')
# Set up the URL for your ESP32 server
url = 'http://192.168.176.195/capture'

# Set up a loop to continuously capture and process images from the ESP32 camera
while True:
    # Send a GET request to the ESP32 server to capture an image
    response = requests.get(url)
    img_bytes = io.BytesIO(response.content).read()

    # Convert the received image bytes to a NumPy array
    img_array = np.frombuffer(img_bytes, dtype=np.uint8)

    # Decode the NumPy array to an OpenCV image
    img = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

    # Preprocess the image
    img = cv2.resize(img, (300, 300))
    x = img.astype('float32')
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.efficientnet.preprocess_input(x)

    # Make prediction
    preds = model.predict(x)
    max_pred = np.max(preds)
    if max_pred < 0.5:
        class_name = "Not Identified"
    else:
        class_idx = np.argmax(preds[0])
        class_name = class_names[class_idx]

    # Display the result on the frame
    cv2.putText(img, "Predicted class: {}".format(class_name), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    cv2.imshow('frame', img)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 112ms/step
